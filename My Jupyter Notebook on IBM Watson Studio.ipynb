# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Md Samiul Huda, Desired Role: Data Scientist**

# %% [markdown]
# *I am interested in data science because I am like to make peoples life easier by going deep inside data and help people to take the best decision*

# %% [markdown]
# ### Basic Additing in Python and Showing the output with print function

# %%
a = 2
b = 4
sum = a + b
print(sum)
# Out:
# 6

# %% [markdown]
# - Main bullet point
#      - Sub bullet point
# 1. Numbered item
# 1. Numbered item
#
# ***
# <a id="section_ID">Test Link</a>
